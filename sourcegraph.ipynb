# %%
# !pip3 install scrapegraphai
# Out:
# Collecting scrapegraphai==0.9.0b7
#   Downloading scrapegraphai-0.9.0b7-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: beautifulsoup4==4.12.3 in /home/codespace/.local/lib/python3.10/site-packages (from scrapegraphai==0.9.0b7) (4.12.3)
# Requirement already satisfied: faiss-cpu==1.8.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from scrapegraphai==0.9.0b7) (1.8.0)
# Requirement already satisfied: free-proxy==1.1.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from scrapegraphai==0.9.0b7) (1.1.1)
# Requirement already satisfied: google==3.0.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from scrapegraphai==0.9.0b7) (3.0.0)
# Collecting graphviz==0.20.1 (from scrapegraphai==0.9.0b7)
#   Downloading graphviz-0.20.1-py3-none-any.whl.metadata (12 kB)
# Collecting html2text==2020.1.16 (from scrapegraphai==0.9.0b7)
#   Downloading html2text-2020.1.16-py3-none-any.whl.metadata (4.3 kB)
# Collecting langchain==0.1.14 (from scrapegraphai==0.9.0b7)
#   Downloading langchain-0.1.14-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: langchain-anthropic<0.2.0,>=0.1.11 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from scrapegraphai==0.9.0b7) (0.1.11)
# Requirement already satisfied: langchain-aws<0.2.0,>=0.1.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from scrapegraphai==0.9.0b7) (0.1.3)
# Collecting langchain-google-genai==1.0.1 (from scrapegraphai==0.9.0b7)
#   Downloading langchain_google_genai-1.0.1-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: langchain-groq==0.1.3 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from scrapegraphai==0.9.0b7) (0.1.3)
# Collecting langchain-openai==0.1.1 (from scrapegraphai==0.9.0b7)
#   Downloading langchain_openai-0.1.1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: minify-html==0.15.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from scrapegraphai==0.9.0b7) (0.15.0)
# Collecting pandas==2.0.3 (from scrapegraphai==0.9.0b7)
#   Downloading pandas-2.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: playwright<2.0.0,>=1.43.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from scrapegraphai==0.9.0b7) (1.43.0)
# Requirement already satisfied: python-dotenv==1.0.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from scrapegraphai==0.9.0b7) (1.0.1)
# Collecting tiktoken<0.6.0,>=0.5.2 (from scrapegraphai==0.9.0b7)
#   Downloading tiktoken-0.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting tqdm==4.66.3 (from scrapegraphai==0.9.0b7)
#   Downloading tqdm-4.66.3-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 690.9 kB/s eta 0:00:00a 0:00:01
# Collecting yahoo-search-py<0.4,>=0.3 (from scrapegraphai==0.9.0b7)
#   Downloading yahoo-search-py-0.3.tar.gz (11 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: soupsieve>1.2 in /home/codespace/.local/lib/python3.10/site-packages (from beautifulsoup4==4.12.3->scrapegraphai==0.9.0b7) (2.5)
# Requirement already satisfied: numpy in /home/codespace/.local/lib/python3.10/site-packages (from faiss-cpu==1.8.0->scrapegraphai==0.9.0b7) (1.26.4)
# Requirement already satisfied: lxml in /usr/local/python/3.10.13/lib/python3.10/site-packages (from free-proxy==1.1.1->scrapegraphai==0.9.0b7) (5.2.2)
# Requirement already satisfied: requests in /home/codespace/.local/lib/python3.10/site-packages (from free-proxy==1.1.1->scrapegraphai==0.9.0b7) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /home/codespace/.local/lib/python3.10/site-packages (from langchain==0.1.14->scrapegraphai==0.9.0b7) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from langchain==0.1.14->scrapegraphai==0.9.0b7) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from langchain==0.1.14->scrapegraphai==0.9.0b7) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from langchain==0.1.14->scrapegraphai==0.9.0b7) (4.0.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from langchain==0.1.14->scrapegraphai==0.9.0b7) (0.6.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from langchain==0.1.14->scrapegraphai==0.9.0b7) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.30 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from langchain==0.1.14->scrapegraphai==0.9.0b7) (0.0.38)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.37 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from langchain==0.1.14->scrapegraphai==0.9.0b7) (0.1.52)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from langchain==0.1.14->scrapegraphai==0.9.0b7) (0.0.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from langchain==0.1.14->scrapegraphai==0.9.0b7) (0.1.83)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from langchain==0.1.14->scrapegraphai==0.9.0b7) (2.8.2)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /home/codespace/.local/lib/python3.10/site-packages (from langchain==0.1.14->scrapegraphai==0.9.0b7) (8.3.0)
# Collecting google-generativeai<0.5.0,>=0.4.1 (from langchain-google-genai==1.0.1->scrapegraphai==0.9.0b7)
#   Downloading google_generativeai-0.4.1-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: groq<1,>=0.4.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from langchain-groq==0.1.3->scrapegraphai==0.9.0b7) (0.9.0)
# Requirement already satisfied: openai<2.0.0,>=1.10.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from langchain-openai==0.1.1->scrapegraphai==0.9.0b7) (1.35.10)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.10/site-packages (from pandas==2.0.3->scrapegraphai==0.9.0b7) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas==2.0.3->scrapegraphai==0.9.0b7) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas==2.0.3->scrapegraphai==0.9.0b7) (2024.1)
# Requirement already satisfied: anthropic<1,>=0.23.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from langchain-anthropic<0.2.0,>=0.1.11->scrapegraphai==0.9.0b7) (0.30.1)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /home/codespace/.local/lib/python3.10/site-packages (from langchain-anthropic<0.2.0,>=0.1.11->scrapegraphai==0.9.0b7) (0.7.1)
# Requirement already satisfied: boto3<1.35.0,>=1.34.51 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from langchain-aws<0.2.0,>=0.1.2->scrapegraphai==0.9.0b7) (1.34.139)
# Requirement already satisfied: greenlet==3.0.3 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from playwright<2.0.0,>=1.43.0->scrapegraphai==0.9.0b7) (3.0.3)
# Requirement already satisfied: pyee==11.1.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from playwright<2.0.0,>=1.43.0->scrapegraphai==0.9.0b7) (11.1.0)
# Requirement already satisfied: typing-extensions in /home/codespace/.local/lib/python3.10/site-packages (from pyee==11.1.0->playwright<2.0.0,>=1.43.0->scrapegraphai==0.9.0b7) (4.12.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tiktoken<0.6.0,>=0.5.2->scrapegraphai==0.9.0b7) (2024.5.15)
# Requirement already satisfied: httpx in /home/codespace/.local/lib/python3.10/site-packages (from yahoo-search-py<0.4,>=0.3->scrapegraphai==0.9.0b7) (0.27.0)
# Collecting selectolax (from yahoo-search-py<0.4,>=0.3->scrapegraphai==0.9.0b7)
#   Downloading selectolax-0.3.21-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: urllib3 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from yahoo-search-py<0.4,>=0.3->scrapegraphai==0.9.0b7) (2.0.7)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.14->scrapegraphai==0.9.0b7) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/codespace/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.14->scrapegraphai==0.9.0b7) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.14->scrapegraphai==0.9.0b7) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.14->scrapegraphai==0.9.0b7) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.14->scrapegraphai==0.9.0b7) (1.9.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/codespace/.local/lib/python3.10/site-packages (from anthropic<1,>=0.23.0->langchain-anthropic<0.2.0,>=0.1.11->scrapegraphai==0.9.0b7) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from anthropic<1,>=0.23.0->langchain-anthropic<0.2.0,>=0.1.11->scrapegraphai==0.9.0b7) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from anthropic<1,>=0.23.0->langchain-anthropic<0.2.0,>=0.1.11->scrapegraphai==0.9.0b7) (0.5.0)
# Requirement already satisfied: sniffio in /home/codespace/.local/lib/python3.10/site-packages (from anthropic<1,>=0.23.0->langchain-anthropic<0.2.0,>=0.1.11->scrapegraphai==0.9.0b7) (1.3.1)
# Requirement already satisfied: tokenizers>=0.13.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from anthropic<1,>=0.23.0->langchain-anthropic<0.2.0,>=0.1.11->scrapegraphai==0.9.0b7) (0.19.1)
# Requirement already satisfied: botocore<1.35.0,>=1.34.139 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from boto3<1.35.0,>=1.34.51->langchain-aws<0.2.0,>=0.1.2->scrapegraphai==0.9.0b7) (1.34.139)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from boto3<1.35.0,>=1.34.51->langchain-aws<0.2.0,>=0.1.2->scrapegraphai==0.9.0b7) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from boto3<1.35.0,>=1.34.51->langchain-aws<0.2.0,>=0.1.2->scrapegraphai==0.9.0b7) (0.10.2)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.14->scrapegraphai==0.9.0b7) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.14->scrapegraphai==0.9.0b7) (0.9.0)
# Collecting google-ai-generativelanguage==0.4.0 (from google-generativeai<0.5.0,>=0.4.1->langchain-google-genai==1.0.1->scrapegraphai==0.9.0b7)
#   Downloading google_ai_generativelanguage-0.4.0-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from google-generativeai<0.5.0,>=0.4.1->langchain-google-genai==1.0.1->scrapegraphai==0.9.0b7) (2.31.0)
# Requirement already satisfied: google-api-core in /usr/local/python/3.10.13/lib/python3.10/site-packages (from google-generativeai<0.5.0,>=0.4.1->langchain-google-genai==1.0.1->scrapegraphai==0.9.0b7) (2.19.1)
# Requirement already satisfied: protobuf in /usr/local/python/3.10.13/lib/python3.10/site-packages (from google-generativeai<0.5.0,>=0.4.1->langchain-google-genai==1.0.1->scrapegraphai==0.9.0b7) (4.25.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from google-ai-generativelanguage==0.4.0->google-generativeai<0.5.0,>=0.4.1->langchain-google-genai==1.0.1->scrapegraphai==0.9.0b7) (1.24.0)
# Requirement already satisfied: certifi in /home/codespace/.local/lib/python3.10/site-packages (from httpx->yahoo-search-py<0.4,>=0.3->scrapegraphai==0.9.0b7) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /home/codespace/.local/lib/python3.10/site-packages (from httpx->yahoo-search-py<0.4,>=0.3->scrapegraphai==0.9.0b7) (1.0.5)
# Requirement already satisfied: idna in /home/codespace/.local/lib/python3.10/site-packages (from httpx->yahoo-search-py<0.4,>=0.3->scrapegraphai==0.9.0b7) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/codespace/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx->yahoo-search-py<0.4,>=0.3->scrapegraphai==0.9.0b7) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/codespace/.local/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain==0.1.14->scrapegraphai==0.9.0b7) (2.4)
# Requirement already satisfied: packaging<24.0,>=23.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from langchain-core<0.2.0,>=0.1.37->langchain==0.1.14->scrapegraphai==0.9.0b7) (23.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.1.14->scrapegraphai==0.9.0b7) (3.10.6)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from pydantic<3,>=1->langchain==0.1.14->scrapegraphai==0.9.0b7) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from pydantic<3,>=1->langchain==0.1.14->scrapegraphai==0.9.0b7) (2.20.1)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas==2.0.3->scrapegraphai==0.9.0b7) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests->free-proxy==1.1.1->scrapegraphai==0.9.0b7) (3.3.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/codespace/.local/lib/python3.10/site-packages (from anyio<5,>=3.5.0->anthropic<1,>=0.23.0->langchain-anthropic<0.2.0,>=0.1.11->scrapegraphai==0.9.0b7) (1.2.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from google-api-core->google-generativeai<0.5.0,>=0.4.1->langchain-google-genai==1.0.1->scrapegraphai==0.9.0b7) (1.63.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from google-auth>=2.15.0->google-generativeai<0.5.0,>=0.4.1->langchain-google-genai==1.0.1->scrapegraphai==0.9.0b7) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from google-auth>=2.15.0->google-generativeai<0.5.0,>=0.4.1->langchain-google-genai==1.0.1->scrapegraphai==0.9.0b7) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from google-auth>=2.15.0->google-generativeai<0.5.0,>=0.4.1->langchain-google-genai==1.0.1->scrapegraphai==0.9.0b7) (4.9)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tokenizers>=0.13.0->anthropic<1,>=0.23.0->langchain-anthropic<0.2.0,>=0.1.11->scrapegraphai==0.9.0b7) (0.23.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain==0.1.14->scrapegraphai==0.9.0b7) (1.0.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-ai-generativelanguage==0.4.0->google-generativeai<0.5.0,>=0.4.1->langchain-google-genai==1.0.1->scrapegraphai==0.9.0b7) (1.64.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-ai-generativelanguage==0.4.0->google-generativeai<0.5.0,>=0.4.1->langchain-google-genai==1.0.1->scrapegraphai==0.9.0b7) (1.62.2)
# Requirement already satisfied: filelock in /home/codespace/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic<1,>=0.23.0->langchain-anthropic<0.2.0,>=0.1.11->scrapegraphai==0.9.0b7) (3.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/codespace/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic<1,>=0.23.0->langchain-anthropic<0.2.0,>=0.1.11->scrapegraphai==0.9.0b7) (2024.5.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai<0.5.0,>=0.4.1->langchain-google-genai==1.0.1->scrapegraphai==0.9.0b7) (0.6.0)
# Downloading scrapegraphai-0.9.0b7-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 1.7 MB/s eta 0:00:0000:01
# Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.0/47.0 kB 1.3 MB/s eta 0:00:00
# Downloading html2text-2020.1.16-py3-none-any.whl (32 kB)
# Downloading langchain-0.1.14-py3-none-any.whl (812 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 812.8/812.8 kB 5.4 MB/s eta 0:00:0000:0100:01
# Downloading langchain_google_genai-1.0.1-py3-none-any.whl (28 kB)
# Downloading langchain_openai-0.1.1-py3-none-any.whl (32 kB)
# Downloading pandas-2.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 38.4 MB/s eta 0:00:0000:0100:01
# Downloading tqdm-4.66.3-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 2.6 MB/s eta 0:00:00
# Downloading tiktoken-0.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 16.0 MB/s eta 0:00:00:00:01
# Downloading google_generativeai-0.4.1-py3-none-any.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.4/137.4 kB 5.3 MB/s eta 0:00:00
# Downloading google_ai_generativelanguage-0.4.0-py3-none-any.whl (598 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 598.7/598.7 kB 18.6 MB/s eta 0:00:00
# Downloading selectolax-0.3.21-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 27.4 MB/s eta 0:00:0000:0100:01
# Building wheels for collected packages: yahoo-search-py
#   Building wheel for yahoo-search-py (pyproject.toml) ... done
#   Created wheel for yahoo-search-py: filename=yahoo_search_py-0.3-py3-none-any.whl size=9733 sha256=ca0aafda1594813f9f0cf02a126d5cc20691e0a5fa329cf67c0493ceb25d7ad5
#   Stored in directory: /home/codespace/.cache/pip/wheels/7f/41/b8/b081679f18726d7c82f04b7db811fa462b7eb204928e9671f3
# Successfully built yahoo-search-py
# Installing collected packages: selectolax, tqdm, html2text, graphviz, tiktoken, pandas, yahoo-search-py, langchain-openai, google-ai-generativelanguage, langchain, google-generativeai, langchain-google-genai, scrapegraphai
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.4
#     Uninstalling tqdm-4.66.4:
#       Successfully uninstalled tqdm-4.66.4
#   Attempting uninstall: html2text
#     Found existing installation: html2text 2024.2.26
#     Uninstalling html2text-2024.2.26:
#       Successfully uninstalled html2text-2024.2.26
#   Attempting uninstall: graphviz
#     Found existing installation: graphviz 0.20.3
#     Uninstalling graphviz-0.20.3:
#       Successfully uninstalled graphviz-0.20.3
#   Attempting uninstall: tiktoken
#     Found existing installation: tiktoken 0.6.0
#     Uninstalling tiktoken-0.6.0:
#       Successfully uninstalled tiktoken-0.6.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: langchain-openai
#     Found existing installation: langchain-openai 0.1.6
#     Uninstalling langchain-openai-0.1.6:
#       Successfully uninstalled langchain-openai-0.1.6
#   Attempting uninstall: google-ai-generativelanguage
#     Found existing installation: google-ai-generativelanguage 0.6.4
#     Uninstalling google-ai-generativelanguage-0.6.4:
#       Successfully uninstalled google-ai-generativelanguage-0.6.4
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.1.15
#     Uninstalling langchain-0.1.15:
#       Successfully uninstalled langchain-0.1.15
#   Attempting uninstall: google-generativeai
#     Found existing installation: google-generativeai 0.5.4
#     Uninstalling google-generativeai-0.5.4:
#       Successfully uninstalled google-generativeai-0.5.4
#   Attempting uninstall: langchain-google-genai
#     Found existing installation: langchain-google-genai 1.0.3
#     Uninstalling langchain-google-genai-1.0.3:
#       Successfully uninstalled langchain-google-genai-1.0.3
#   Attempting uninstall: scrapegraphai
#     Found existing installation: scrapegraphai 1.8.0
#     Uninstalling scrapegraphai-1.8.0:
#       Successfully uninstalled scrapegraphai-1.8.0
# Successfully installed google-ai-generativelanguage-0.4.0 google-generativeai-0.4.1 graphviz-0.20.1 html2text-2020.1.16 langchain-0.1.14 langchain-google-genai-1.0.1 langchain-openai-0.1.1 pandas-2.0.3 scrapegraphai-0.9.0b7 selectolax-0.3.21 tiktoken-0.5.2 tqdm-4.66.3 yahoo-search-py-0.3
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
# !playwright install
# Out:
# Playwright Host validation warning:
# ╔══════════════════════════════════════════════════════╗
# ║ Host system is missing dependencies to run browsers. ║
# ║ Missing libraries:                                   ║
# ║     libwoff2dec.so.1.0.2                             ║
# ║     libopus.so.0                                     ║
# ║     libwebpdemux.so.2                                ║
# ║     libharfbuzz-icu.so.0                             ║
# ║     libenchant-2.so.2                                ║
# ║     libhyphen.so.0                                   ║
# ║     libflite.so.1                                    ║
# ║     libflite_usenglish.so.1                          ║
# ║     libflite_cmu_grapheme_lang.so.1                  ║
# ║     libflite_cmu_grapheme_lex.so.1                   ║
# ║     libflite_cmu_indic_lang.so.1                     ║
# ║     libflite_cmu_indic_lex.so.1                      ║
# ║     libflite_cmulex.so.1                             ║
# ║     libflite_cmu_time_awb.so.1                       ║
# ║     libflite_cmu_us_awb.so.1                         ║
# ║     libflite_cmu_us_kal16.so.1                       ║
# ║     libflite_cmu_us_kal.so.1                         ║
# ║     libflite_cmu_us_rms.so.1                         ║
# ║     libflite_cmu_us_slt.so.1                         ║
# ║     libEGL.so.1                                      ║
# ║     libGLX.so.0                                      ║
# ║     libgudev-1.0.so.0                                ║
# ║     libevdev.so.2                                    ║
# ║     libGLESv2.so.2                                   ║
# ║     libx264.so                                       ║
# ╚══════════════════════════════════════════════════════╝
#     at validateDependenciesLinux (/usr/local/python/3.10.13/lib/python3.10/site-packages/playwright/driver/package/lib/server/registry/dependencies.js:216:9)
#     at process.processTicksAndRejections (node:internal/process/task_queues:95:5)
#     at async Registry._validateHostRequirements (/usr/local/python/3.10.13/lib/python3.10/site-packages/playwright/driver/package/lib/server/registry/index.js:587:43)
#     at async Registry._validateHostRequirementsForExecutableIfNeeded (/usr/local/python/3.10.13/lib/python3.10/site-packages/playwright/driver/package/lib/server/registry/index.js:685:7)
#     at async Registry.validateHostRequirementsForExecutablesIfNeeded (/usr/local/python/3.10.13/lib/python3.10/site-packages/playwright/driver/package/lib/server/registry/index.js:674:43)
#     at async t.<anonymous> (/usr/local/python/3.10.13/lib/python3.10/site-packages/playwright/driver/package/lib/cli/program.js:119:7)

# %%
# !ollama pull mistral
# Out:
# /bin/bash: ollama: command not found

# %%
#!ollama pull nomic-embed-text

# %%
from scrapegraphai.graphs import SmartScraperGraph # type: ignore

# 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
graph_config = {
    "llm": {
        "api_key": "AIzaSyCfQtJCyn37hV1dOpHze3do1wL9JPwLC9U",
        "model": "gemini-pro"
    },
}

# %%
smart_scraper_graph = SmartScraperGraph(
   prompt="List me all the projects with their description.",
   # also accepts a string with the already downloaded HTML code
   source="https://perinim.github.io/projects",
   config=graph_config
)

result = smart_scraper_graph.run()
print(result)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/urllib3/connection.py:203, in HTTPConnection._new_conn(self)
#     202 try:
# --> 203     sock = connection.create_connection(
#     204         (self._dns_host, self.port),
#     205         self.timeout,
#     206         source_address=self.source_address,
#     207         socket_options=self.socket_options,
#     208     )
#     209 except socket.gaierror as e:
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# NewConnectionError                        Traceback (most recent call last)
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/urllib3/connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
#     802     decode_content=decode_content,
#     803     **response_kw,
#     804 )
#     806 # Everything went great!
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/urllib3/connectionpool.py:497, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     496 try:
# --> 497     conn.request(
#     498         method,
#     499         url,
#     500         body=body,
#     501         headers=headers,
#     502         chunked=chunked,
#     503         preload_content=preload_content,
#     504         decode_content=decode_content,
#     505         enforce_content_length=enforce_content_length,
#     506     )
#     508 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     509 # legitimately able to close the connection after sending a valid response.
#     510 # With this behaviour, the received response is still readable.
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/urllib3/connection.py:395, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     394     self.putheader(header, value)
# --> 395 self.endheaders()
#     397 # If we're given a body we start sending that in chunks.
#
# File /usr/local/python/3.10.13/lib/python3.10/http/client.py:1278, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1277     raise CannotSendHeader()
# -> 1278 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /usr/local/python/3.10.13/lib/python3.10/http/client.py:1038, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1037 del self._buffer[:]
# -> 1038 self.send(msg)
#    1040 if message_body is not None:
#    1041
#    1042     # create a consistent interface to message_body
#
# File /usr/local/python/3.10.13/lib/python3.10/http/client.py:976, in HTTPConnection.send(self, data)
#     975 if self.auto_open:
# --> 976     self.connect()
#     977 else:
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/urllib3/connection.py:243, in HTTPConnection.connect(self)
#     242 def connect(self) -> None:
# --> 243     self.sock = self._new_conn()
#     244     if self._tunnel_host:
#     245         # If we're tunneling it means we're connected to our proxy.
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/urllib3/connection.py:218, in HTTPConnection._new_conn(self)
#     217 except OSError as e:
# --> 218     raise NewConnectionError(
#     219         self, f"Failed to establish a new connection: {e}"
#     220     ) from e
#     222 # Audit hooks are only available in Python 3.8+
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7e6d519aa710>: Failed to establish a new connection: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/urllib3/connectionpool.py:845, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     843     new_e = ProtocolError("Connection aborted.", new_e)
# --> 845 retries = retries.increment(
#     846     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     847 )
#     848 retries.sleep()
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/urllib3/util/retry.py:515, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     514     reason = error or ResponseError(cause)
# --> 515     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     517 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/embeddings (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7e6d519aa710>: Failed to establish a new connection: [Errno 111] Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/langchain_community/embeddings/ollama.py:164, in OllamaEmbeddings._process_emb_response(self, input)
#     163 try:
# --> 164     res = requests.post(
#     165         f"{self.base_url}/api/embeddings",
#     166         headers=headers,
#     167         json={"model": self.model, "prompt": input, **self._default_params},
#     168     )
#     169 except requests.exceptions.RequestException as e:
#
# File ~/.local/lib/python3.10/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     104 r"""Sends a POST request.
#     105
#     106 :param url: URL for the new :class:`Request` object.
#    (...)
#     112 :rtype: requests.Response
#     113 """
# --> 115 return request("post", url, data=data, json=json, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File ~/.local/lib/python3.10/site-packages/requests/adapters.py:700, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     698         raise SSLError(e, request=request)
# --> 700     raise ConnectionError(e, request=request)
#     702 except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/embeddings (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7e6d519aa710>: Failed to establish a new connection: [Errno 111] Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 8
#       1 smart_scraper_graph = SmartScraperGraph(
#       2    prompt="List me all the projects with their description.",
#       3    # also accepts a string with the already downloaded HTML code
#       4    source="https://perinim.github.io/projects",
#       5    config=graph_config
#       6 )
# ----> 8 result = smart_scraper_graph.run()
#       9 print(result)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/scrapegraphai/graphs/smart_scraper_graph.py:120, in SmartScraperGraph.run(self)
#     112 """
#     113 Executes the scraping process and returns the answer to the prompt.
#     114
#     115 Returns:
#     116     str: The answer to the prompt.
#     117 """
#     119 inputs = {"user_prompt": self.prompt, self.input_key: self.source}
# --> 120 self.final_state, self.execution_info = self.graph.execute(inputs)
#     122 return self.final_state.get("answer", "No answer found.")
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/scrapegraphai/graphs/base_graph.py:224, in BaseGraph.execute(self, initial_state)
#     222     return (result["_state"], [])
#     223 else:
# --> 224     return self._execute_standard(initial_state)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/scrapegraphai/graphs/base_graph.py:153, in BaseGraph._execute_standard(self, initial_state)
#     144     graph_execution_time = time.time() - start_time
#     145     log_graph_execution(
#     146         graph_name=self.graph_name,
#     147         llm_model=llm_model,
#    (...)
#     151         error_node=error_node
#     152     )
# --> 153     raise e
#     154 node_exec_time = time.time() - curr_time
#     155 total_exec_time += node_exec_time
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/scrapegraphai/graphs/base_graph.py:140, in BaseGraph._execute_standard(self, initial_state)
#     138 with get_openai_callback() as cb:
#     139     try:
# --> 140         result = current_node.execute(state)
#     141     except Exception as e:
#     142         error_node = current_node.node_name
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/scrapegraphai/nodes/rag_node.py:118, in RAGNode.execute(self, state)
#     115     self.logger.info("--- (indexes loaded from cache) ---")
#     117 else:
# --> 118     index = FAISS.from_documents(chunked_docs, embeddings)
#     120 retriever = index.as_retriever()
#     122 redundant_filter = EmbeddingsRedundantFilter(embeddings=embeddings)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/langchain_core/vectorstores.py:550, in VectorStore.from_documents(cls, documents, embedding, **kwargs)
#     548 texts = [d.page_content for d in documents]
#     549 metadatas = [d.metadata for d in documents]
# --> 550 return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/langchain_community/vectorstores/faiss.py:930, in FAISS.from_texts(cls, texts, embedding, metadatas, ids, **kwargs)
#     903 @classmethod
#     904 def from_texts(
#     905     cls,
#    (...)
#     910     **kwargs: Any,
#     911 ) -> FAISS:
#     912     """Construct FAISS wrapper from raw documents.
#     913
#     914     This is a user friendly interface that:
#    (...)
#     928             faiss = FAISS.from_texts(texts, embeddings)
#     929     """
# --> 930     embeddings = embedding.embed_documents(texts)
#     931     return cls.__from(
#     932         texts,
#     933         embeddings,
#    (...)
#     937         **kwargs,
#     938     )
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/langchain_community/embeddings/ollama.py:211, in OllamaEmbeddings.embed_documents(self, texts)
#     202 """Embed documents using an Ollama deployed embedding model.
#     203
#     204 Args:
#    (...)
#     208     List of embeddings, one for each text.
#     209 """
#     210 instruction_pairs = [f"{self.embed_instruction}{text}" for text in texts]
# --> 211 embeddings = self._embed(instruction_pairs)
#     212 return embeddings
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/langchain_community/embeddings/ollama.py:199, in OllamaEmbeddings._embed(self, input)
#     197 else:
#     198     iter_ = input
# --> 199 return [self._process_emb_response(prompt) for prompt in iter_]
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/langchain_community/embeddings/ollama.py:199, in <listcomp>(.0)
#     197 else:
#     198     iter_ = input
# --> 199 return [self._process_emb_response(prompt) for prompt in iter_]
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/langchain_community/embeddings/ollama.py:170, in OllamaEmbeddings._process_emb_response(self, input)
#     164     res = requests.post(
#     165         f"{self.base_url}/api/embeddings",
#     166         headers=headers,
#     167         json={"model": self.model, "prompt": input, **self._default_params},
#     168     )
#     169 except requests.exceptions.RequestException as e:
# --> 170     raise ValueError(f"Error raised by inference endpoint: {e}")
#     172 if res.status_code != 200:
#     173     raise ValueError(
#     174         "Error raised by inference API HTTP code: %s, %s"
#     175         % (res.status_code, res.text)
#     176     )
#
# ValueError: Error raised by inference endpoint: HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/embeddings (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7e6d519aa710>: Failed to establish a new connection: [Errno 111] Connection refused'))

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
result = smart_scraper_graph.run()
print(result)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/urllib3/connection.py:203, in HTTPConnection._new_conn(self)
#     202 try:
# --> 203     sock = connection.create_connection(
#     204         (self._dns_host, self.port),
#     205         self.timeout,
#     206         source_address=self.source_address,
#     207         socket_options=self.socket_options,
#     208     )
#     209 except socket.gaierror as e:
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# NewConnectionError                        Traceback (most recent call last)
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/urllib3/connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
#     802     decode_content=decode_content,
#     803     **response_kw,
#     804 )
#     806 # Everything went great!
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/urllib3/connectionpool.py:497, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     496 try:
# --> 497     conn.request(
#     498         method,
#     499         url,
#     500         body=body,
#     501         headers=headers,
#     502         chunked=chunked,
#     503         preload_content=preload_content,
#     504         decode_content=decode_content,
#     505         enforce_content_length=enforce_content_length,
#     506     )
#     508 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     509 # legitimately able to close the connection after sending a valid response.
#     510 # With this behaviour, the received response is still readable.
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/urllib3/connection.py:395, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     394     self.putheader(header, value)
# --> 395 self.endheaders()
#     397 # If we're given a body we start sending that in chunks.
#
# File /usr/local/python/3.10.13/lib/python3.10/http/client.py:1278, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1277     raise CannotSendHeader()
# -> 1278 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /usr/local/python/3.10.13/lib/python3.10/http/client.py:1038, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1037 del self._buffer[:]
# -> 1038 self.send(msg)
#    1040 if message_body is not None:
#    1041
#    1042     # create a consistent interface to message_body
#
# File /usr/local/python/3.10.13/lib/python3.10/http/client.py:976, in HTTPConnection.send(self, data)
#     975 if self.auto_open:
# --> 976     self.connect()
#     977 else:
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/urllib3/connection.py:243, in HTTPConnection.connect(self)
#     242 def connect(self) -> None:
# --> 243     self.sock = self._new_conn()
#     244     if self._tunnel_host:
#     245         # If we're tunneling it means we're connected to our proxy.
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/urllib3/connection.py:218, in HTTPConnection._new_conn(self)
#     217 except OSError as e:
# --> 218     raise NewConnectionError(
#     219         self, f"Failed to establish a new connection: {e}"
#     220     ) from e
#     222 # Audit hooks are only available in Python 3.8+
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7e6d51727070>: Failed to establish a new connection: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/urllib3/connectionpool.py:845, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     843     new_e = ProtocolError("Connection aborted.", new_e)
# --> 845 retries = retries.increment(
#     846     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     847 )
#     848 retries.sleep()
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/urllib3/util/retry.py:515, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     514     reason = error or ResponseError(cause)
# --> 515     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     517 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/embeddings (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7e6d51727070>: Failed to establish a new connection: [Errno 111] Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/langchain_community/embeddings/ollama.py:164, in OllamaEmbeddings._process_emb_response(self, input)
#     163 try:
# --> 164     res = requests.post(
#     165         f"{self.base_url}/api/embeddings",
#     166         headers=headers,
#     167         json={"model": self.model, "prompt": input, **self._default_params},
#     168     )
#     169 except requests.exceptions.RequestException as e:
#
# File ~/.local/lib/python3.10/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     104 r"""Sends a POST request.
#     105
#     106 :param url: URL for the new :class:`Request` object.
#    (...)
#     112 :rtype: requests.Response
#     113 """
# --> 115 return request("post", url, data=data, json=json, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File ~/.local/lib/python3.10/site-packages/requests/adapters.py:700, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     698         raise SSLError(e, request=request)
# --> 700     raise ConnectionError(e, request=request)
#     702 except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/embeddings (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7e6d51727070>: Failed to establish a new connection: [Errno 111] Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 result = smart_scraper_graph.run()
#       2 print(result)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/scrapegraphai/graphs/smart_scraper_graph.py:120, in SmartScraperGraph.run(self)
#     112 """
#     113 Executes the scraping process and returns the answer to the prompt.
#     114
#     115 Returns:
#     116     str: The answer to the prompt.
#     117 """
#     119 inputs = {"user_prompt": self.prompt, self.input_key: self.source}
# --> 120 self.final_state, self.execution_info = self.graph.execute(inputs)
#     122 return self.final_state.get("answer", "No answer found.")
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/scrapegraphai/graphs/base_graph.py:224, in BaseGraph.execute(self, initial_state)
#     222     return (result["_state"], [])
#     223 else:
# --> 224     return self._execute_standard(initial_state)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/scrapegraphai/graphs/base_graph.py:153, in BaseGraph._execute_standard(self, initial_state)
#     144     graph_execution_time = time.time() - start_time
#     145     log_graph_execution(
#     146         graph_name=self.graph_name,
#     147         llm_model=llm_model,
#    (...)
#     151         error_node=error_node
#     152     )
# --> 153     raise e
#     154 node_exec_time = time.time() - curr_time
#     155 total_exec_time += node_exec_time
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/scrapegraphai/graphs/base_graph.py:140, in BaseGraph._execute_standard(self, initial_state)
#     138 with get_openai_callback() as cb:
#     139     try:
# --> 140         result = current_node.execute(state)
#     141     except Exception as e:
#     142         error_node = current_node.node_name
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/scrapegraphai/nodes/rag_node.py:118, in RAGNode.execute(self, state)
#     115     self.logger.info("--- (indexes loaded from cache) ---")
#     117 else:
# --> 118     index = FAISS.from_documents(chunked_docs, embeddings)
#     120 retriever = index.as_retriever()
#     122 redundant_filter = EmbeddingsRedundantFilter(embeddings=embeddings)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/langchain_core/vectorstores.py:550, in VectorStore.from_documents(cls, documents, embedding, **kwargs)
#     548 texts = [d.page_content for d in documents]
#     549 metadatas = [d.metadata for d in documents]
# --> 550 return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/langchain_community/vectorstores/faiss.py:930, in FAISS.from_texts(cls, texts, embedding, metadatas, ids, **kwargs)
#     903 @classmethod
#     904 def from_texts(
#     905     cls,
#    (...)
#     910     **kwargs: Any,
#     911 ) -> FAISS:
#     912     """Construct FAISS wrapper from raw documents.
#     913
#     914     This is a user friendly interface that:
#    (...)
#     928             faiss = FAISS.from_texts(texts, embeddings)
#     929     """
# --> 930     embeddings = embedding.embed_documents(texts)
#     931     return cls.__from(
#     932         texts,
#     933         embeddings,
#    (...)
#     937         **kwargs,
#     938     )
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/langchain_community/embeddings/ollama.py:211, in OllamaEmbeddings.embed_documents(self, texts)
#     202 """Embed documents using an Ollama deployed embedding model.
#     203
#     204 Args:
#    (...)
#     208     List of embeddings, one for each text.
#     209 """
#     210 instruction_pairs = [f"{self.embed_instruction}{text}" for text in texts]
# --> 211 embeddings = self._embed(instruction_pairs)
#     212 return embeddings
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/langchain_community/embeddings/ollama.py:199, in OllamaEmbeddings._embed(self, input)
#     197 else:
#     198     iter_ = input
# --> 199 return [self._process_emb_response(prompt) for prompt in iter_]
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/langchain_community/embeddings/ollama.py:199, in <listcomp>(.0)
#     197 else:
#     198     iter_ = input
# --> 199 return [self._process_emb_response(prompt) for prompt in iter_]
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/langchain_community/embeddings/ollama.py:170, in OllamaEmbeddings._process_emb_response(self, input)
#     164     res = requests.post(
#     165         f"{self.base_url}/api/embeddings",
#     166         headers=headers,
#     167         json={"model": self.model, "prompt": input, **self._default_params},
#     168     )
#     169 except requests.exceptions.RequestException as e:
# --> 170     raise ValueError(f"Error raised by inference endpoint: {e}")
#     172 if res.status_code != 200:
#     173     raise ValueError(
#     174         "Error raised by inference API HTTP code: %s, %s"
#     175         % (res.status_code, res.text)
#     176     )
#
# ValueError: Error raised by inference endpoint: HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/embeddings (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7e6d51727070>: Failed to establish a new connection: [Errno 111] Connection refused'))

# %%
import pandas as pd
# Creating a DataFrame
df = pd.DataFrame(result['articles'])
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 import pandas as pd
#       2 # Creating a DataFrame
# ----> 3 df = pd.DataFrame(result['articles'])
#       4 df
#
# NameError: name 'result' is not defined
