# %%
# !pip3 install scrapegraphai
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
# !playwright install
# Out:
# Playwright Host validation warning:
# ╔══════════════════════════════════════════════════════╗
# ║ Host system is missing dependencies to run browsers. ║
# ║ Missing libraries:                                   ║
# ║     libwoff2dec.so.1.0.2                             ║
# ║     libopus.so.0                                     ║
# ║     libwebpdemux.so.2                                ║
# ║     libharfbuzz-icu.so.0                             ║
# ║     libenchant-2.so.2                                ║
# ║     libhyphen.so.0                                   ║
# ║     libflite.so.1                                    ║
# ║     libflite_usenglish.so.1                          ║
# ║     libflite_cmu_grapheme_lang.so.1                  ║
# ║     libflite_cmu_grapheme_lex.so.1                   ║
# ║     libflite_cmu_indic_lang.so.1                     ║
# ║     libflite_cmu_indic_lex.so.1                      ║
# ║     libflite_cmulex.so.1                             ║
# ...

# %%
from scrapegraphai.graphs import SmartScraperGraph # type: ignore

# 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
graph_config = {
    "llm": {
        "api_key": "AIzaSyCfQtJCyn37hV1dOpHze3do1wL9JPwLC9U",
        "model": "gemini-pro"
    },
}

# %%
# !pip install nest_asyncio
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import nest_asyncio
nest_asyncio.apply()

smart_scraper_graph = SmartScraperGraph(
    prompt="List me 100 jobs all detales",
    source="https://www.linkedin.com/jobs/search/?&keywords=data%20scientist",
    config=graph_config
)

result = smart_scraper_graph.run()
print(result)
# Out:
# {'jobs': [{'title': 'Data Scientist I, Marketing Analytics', 'company': 'Tinder', 'location': 'West Hollywood, CA', 'date_posted': '1 day ago'}, {'title': 'Data Scientist, Product', 'company': 'Notion', 'location': 'San Francisco, CA', 'date_posted': '1 week ago'}, {'title': 'Data Scientist', 'company': 'Flock Freight', 'location': 'Encinitas, CA', 'date_posted': '2 days ago'}, {'title': 'Data Scientist (L5) - Content & Marketing DSE', 'company': 'Netflix', 'location': 'Los Angeles, CA', 'date_posted': '1 week ago'}, {'title': 'Data Scientist, Product Analytics', 'company': 'Etsy', 'location': 'Brooklyn, NY', 'date_posted': '1 week ago'}, {'title': 'Data Scientist', 'company': 'Analytica', 'location': 'Washington, DC', 'date_posted': '1 week ago'}, {'title': 'Staff Data Scientist, Strategy & Insights', 'company': 'LinkedIn', 'location': 'Sunnyvale, CA', 'date_posted': '1 week ago'}, {'title': 'Data Scientist', 'company': 'Glo', 'location': 'San Francisco, CA', 'date_posted': '3 days 
# ...

# %%
import pandas as pd
# Creating a DataFrame
df = pd.DataFrame(result['jobs'])
df
# Out:
#                                             title  \
# 0           Data Scientist I, Marketing Analytics
# 1                         Data Scientist, Product
# 2                                  Data Scientist
# 3   Data Scientist (L5) - Content & Marketing DSE
# 4               Data Scientist, Product Analytics
# 5                                  Data Scientist
# 6       Staff Data Scientist, Strategy & Insights
# 7                                  Data Scientist
# 8                                 Data Scientists
# 9                                  Data Scientist
# 10                   Data Scientist (Direct Hire)
# 11                   Data Scientist (Direct Hire)
# 12                                   Data Science
# 13                                 Data Scientist
# 14                          Junior Data Scientist
# 15                                Data Scientists
# 16                                 Data Scientist
# 17                   Data Scientist (Direct Hire)
# ...
